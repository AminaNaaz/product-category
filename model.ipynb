# %%
import flask

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('weight.csv')
df
df.dropna(axis=0,inplace=True)
df['item_Name'].unique()
X=df.iloc[:,1:2]
X
# Out:
#                                         package_item_name
# 53777   My Hero Academia, Vol. 28 (Volume 28) Paperbac...
# 53778                            Ventilation window mould
# 53779   Tommy Hilfiger Men Pink Solid Polo Collar t-shirt
# 53780                              dress and wedding item
# 53781                              Decoding Communication
# ...                                                   ...
# 176959  Thanu's Crafts Sexy Women Black Anklet Threade...
# 176960  Webcam Cover Slide,Ultra Thin Laptop Camera Cover
# 176961                                 Artificial Jewelry
# 176962                               Artificial jewellery
# 176963                               Artificial jewellery
#
# [119689 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder
y =df['item_Name']

encoder = LabelEncoder()
y = encoder.fit_transform(y)
import texthero as hero

new_X = hero.clean(X['package_item_name'])

new_X
hero.wordcloud(new_X .pipe(hero.clean))

# %%
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
import nltk
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
import re
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import numpy as np
from sklearn.metrics import confusion_matrix

# %%
rf = Pipeline([
   ('vect', CountVectorizer(analyzer="word", stop_words="english")),   
   ('tfidf', TfidfTransformer(use_idf=True)),
   ('clf', RandomForestClassifier()) ])
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
v = dict(zip(list(y), df['item_Name'].to_list()))
rf.fit(x_train['package_item_name'].to_list(), list(y_train))  
X_TEST = x_test['package_item_name'].to_list()
Y_TEST = list(y_test)
predicted = rf.predict(X_TEST)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,predicted)*100
# Out:
# 87.70573982788872

# %%
pickle.dump(rf, open('model.pkl','wb'))

# %%
import flask
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import pandas as pd
import seaborn as sns
df=pd.read_csv('weight.csv')
df
df.dropna(axis=0,inplace=True)
df['item_Name'].unique()
X=df.iloc[:,1:2]
X
from sklearn.preprocessing import LabelEncoder
y =df['item_Name']

encoder = LabelEncoder()
y = encoder.fit_transform(y)
import texthero as hero

new_X = hero.clean(X['package_item_name'])

new_X
hero.wordcloud(new_X .pipe(hero.clean))

# %%
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
import nltk
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
import re
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import numpy as np
from sklearn.metrics import confusion_matrix
rf = Pipeline([
   ('vect', CountVectorizer(analyzer="word", stop_words="english")),   
   ('tfidf', TfidfTransformer(use_idf=True)),
   ('clf', RandomForestClassifier()) ])
pickle.dump(CountVectorizer, open('tranform.pkl', 'wb'))

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
v = dict(zip(list(y), df['item_Name'].to_list()))
rf.fit(x_train['package_item_name'].to_list(), list(y_train))  
X_TEST = x_test['package_item_name'].to_list()
Y_TEST = list(y_test)
predicted = rf.predict(X_TEST)

from sklearn.metrics import accuracy_score
accuracy_score(y_test,predicted)*100
filename = 'nlp_model.pkl'
pickle.dump(rf, open(filename, 'wb'))
